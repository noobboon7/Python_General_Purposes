# %%
import requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-95039fbd75c1> in <module>
# ----> 1 import requests
#
# ModuleNotFoundError: No module named 'requests'

# %%
import bs4

# %%
result = requests.get("https://en.wikipedia.org/w/index.php?title=Wikipedia&banner=S2021_1123_enUS_dsk_lg_control&force=1&country=US&utm_campaign=C2021_social&utm_medium=google&utm_source=enUS2021_fr_search_brand_wikipedia_WPArticlePage_var2_text")

# %%
soup = bs4.BeautifulSoup(result.text,'lxml')

# %%
soup.select('title')[0].getText() #getting a single element text
# Out:
# 'Wikipedia - Wikipedia'

# %%
for item in soup.select('.toctext'): #grabing list of content from wikipedia home page
    print(item.text)
# Out:
# History
# Nupedia
# Launch and early growth
# Milestones
# Openness
# Restrictions
# Review of changes
# Vandalism
# Edit warring
# Policies and laws
# Content policies and guidelines
# Governance
# Administrators
# Dispute resolution
# Arbitration Committee
# Community
# Studies
# Diversity
# Language editions
# English Wikipedia editor decline
# Reception
# Accuracy of content
# Discouragement in education
# Medical information
# Quality of writing
# Coverage of topics and systemic bias
# Coverage of topics and selection bias
# Systemic bias
# Explicit content
# Privacy
# Sexism
# Operation
# Wikimedia Foundation and Wikimedia movement affiliates
# Software operations and support
# Automated editing
# Hardware operations and support
# Internal research and operational development
# Internal news publications
# Access to content
# Content licensing
# Methods of access
# Mobile access
# Cultural impact
# Trusted source to combat fake news
# Readership
# COVID-19 pandemic
# ...

# %%
res = requests.get("https://en.wikipedia.org/wiki/COVID-19_pandemic")
soup = bs4.BeautifulSoup(res.text, "lxml")
comp = soup.select(".thumbimage img")[0]

print(comp)

img_link = requests.get(f'https:{comp["src"]}')

file = open('WP_covid_nurse.jpg', 'wb')

file.write(img_link.content)

file.close()
# Out:
# <img alt="A nurse caring for a patient with COVID‑19 in an intensive care unit" data-file-height="1024" data-file-width="1123" decoding="async" height="263" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d3/COVID-19_Nurse_%28cropped%29.jpg/288px-COVID-19_Nurse_%28cropped%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d3/COVID-19_Nurse_%28cropped%29.jpg/432px-COVID-19_Nurse_%28cropped%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d3/COVID-19_Nurse_%28cropped%29.jpg/576px-COVID-19_Nurse_%28cropped%29.jpg 2x" width="288"/>

# %%
endPoint = "https://books.toscrape.com/"
page = 1
catalogue = f'catalogue/page-{page}.html'

req = requests.get(f'{endPoint}{catalogue}')
while req.status_code == 200:
    page = 1
    catalogue = f'catalogue/page-{page}.html'
    print(f'{endPoint}{catalogue}')
    page += 1




res = bs4.BeautifulSoup(req.text, 'lxml')

imgs = res.select('.image_container img')

# for img in imgs:
#     img
# for img in imgs:
#     img_link = requests.get(f'{endPoint}{img["src"]}')
    
#     img_file = open(f'./Book_store_images/{img["alt"]}.jpg', 'wb')
#     img_file.write(img_link.content)
#     img_file.close()
# Out:
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-1.html
# ...
